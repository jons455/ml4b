# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.cluster import KMeans
import re
import preprocessor as p#forming a separate feature for cleaned tweets
import string
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
from sklearn.metrics import adjusted_rand_score
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alexkroeker/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = []
for file in range(14):
    data.append(open('Tweet-Data/Digital_Counterpart_tweets-'+str(2007+file)+'.jl'))

# %%
doc = []
for file in data:
    for line in file:
        doc.append(json.loads(line))

# %%
emptyList = []
for dict in doc:
    emptyList.append(dict['response'])
    
len(emptyList)
# Out:
# 22

# %%
def check(dictionary):
    if dictionary['result_count'] == 0: return False
    else: return True

# %%
emptyData = []
for dict in emptyList:
    if check(dict['meta']): emptyData.append(dict['data'])
len(emptyData)
# Out:
# 22

# %%
pd.DataFrame(emptyData[2])
# Out:
#    reply_settings              source author_id lang  \
# 0        everyone  Twitter Web Client  79282355   en
# 1        everyone  Twitter Web Client  19008999   en
# 2        everyone  Twitter Web Client  14633924   en
# 3        everyone  Twitter Web Client  15413016   en
# 4        everyone  Twitter Web Client  23929155   en
# 5        everyone  Twitter Web Client  81211419   en
# 6        everyone  Twitter Web Client  21632675   en
# 7        everyone  Twitter Web Client  23613197   en
# 8        everyone  Twitter Web Client  14327828   en
# 9        everyone         twitterfeed  15167706   en
# 10       everyone  Twitter Web Client  21917843   en
# 11       everyone  Twitter Web Client  19933416   en
# 12       everyone  Twitter Web Client  15463179   en
# 13       everyone        SocialEngage  16783458   en
# 14       everyone  Twitter Web Client    756471   en
# 15       everyone  Twitter Web Client  10509002   en
# 16       everyone  Twitter Web Client  46647398   en
# 17       everyone  Twitter Web Client  14658472   en
# 18       everyone           TweetChat  14336472   en
# 19       everyone  Twitter Web Client  22339968   en
# 20       everyone  Twitter Web Client   8551622   en
# 21       everyone  Twitter Web Client  48270870   en
# 22       everyone  Twitter Web Client  14440540   en
# 23       everyone  Twitter Web Client  15010721   en
# 24       everyone  Twitter Web Client  15029022   en
# 25       everyone  Twitter Web Client  15398053   en
# 26       everyone  Twitter Web Client  18845327   en
# 27       everyone  Twitter Web Client  16337671   en
# 28       everyone  Twitter Web Client  14896500   en
# 29       everyone  Twitter Web Client    665023   en
# 30       everyone  Twitter Web Client      8412   en
# 31       everyone  Twitter Web Client   3638231   en
# 32       everyone  Twitter Web Client  14801455   de
# 33       everyone  Twitter Web Client  14151522   en
# 34       everyone  Twitter Web Client  15904286   en
# 35       everyone  Twitter Web Client  15676138   en
#
#                                              entities conversation_id  \
# 0   {'hashtags': [{'start': 128, 'end': 137, 'tag'...      7124239706
# 1   {'mentions': [{'start': 0, 'end': 7, 'username...      6817077662
# 2   {'hashtags': [{'start': 128, 'end': 136, 'tag'...      6666367314
# 3   {'annotations': [{'start': 30, 'end': 44, 'pro...      6579522012
# 4                                                 NaN      5831602627
# 5                                                 NaN      5325182843
# 6   {'mentions': [{'start': 0, 'end': 10, 'usernam...      5230536685
# 7   {'mentions': [{'start': 3, 'end': 11, 'usernam...      5203312011
# 8   {'annotations': [{'start': 18, 'end': 23, 'pro...      4606126236
# 9   {'annotations': [{'start': 25, 'end': 35, 'pro...      3672866109
# 10  {'mentions': [{'start': 3, 'end': 14, 'usernam...      3582429334
# 11  {'mentions': [{'start': 3, 'end': 14, 'usernam...      3582346717
# 12  {'mentions': [{'start': 92, 'end': 103, 'usern...      3582175221
# 13                                                NaN      3582143508
# 14  {'mentions': [{'start': 0, 'end': 12, 'usernam...      3384362162
# 15  {'annotations': [{'start': 7, 'end': 12, 'prob...      3307178956
# 16  {'annotations': [{'start': 100, 'end': 118, 'p...      3164536621
# 17  {'mentions': [{'start': 0, 'end': 4, 'username...      3089184966
# 18  {'hashtags': [{'start': 12, 'end': 15, 'tag': ...      2940263931
# 19                                                NaN      2657464202
# 20                                                NaN      2414529462
# 21  {'mentions': [{'start': 0, 'end': 14, 'usernam...      2287143754
# 22                                                NaN      2196619430
# 23  {'annotations': [{'start': 85, 'end': 97, 'pro...      2132093530
# 24                                                NaN      2134326720
# 25  {'mentions': [{'start': 0, 'end': 13, 'usernam...      2132271168
# 26  {'annotations': [{'start': 0, 'end': 13, 'prob...      1994790951
# 27  {'annotations': [{'start': 0, 'end': 8, 'proba...      1993679664
# 28  {'mentions': [{'start': 121, 'end': 135, 'user...      1640441971
# 29  {'mentions': [{'start': 0, 'end': 14, 'usernam...      1638350377
# 30                                                NaN      1638350377
# 31  {'annotations': [{'start': 118, 'end': 122, 'p...      1510383642
# 32                                                NaN      1408236594
# 33                                                NaN      1243755867
# 34                                                NaN      1153044281
# 35  {'mentions': [{'start': 0, 'end': 16, 'usernam...      1149145192
#
#                                        public_metrics  possibly_sensitive  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 2   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 3   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 4   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 5   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 6   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 7   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 8   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 9   {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 10  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 11  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 12  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 13  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 14  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 15  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 16  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 17  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 18  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 19  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 20  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 21  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 22  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 23  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 24  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 25  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 26  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 27  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 28  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 29  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 30  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 31  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 32  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 33  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 34  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
# 35  {'retweet_count': 0, 'reply_count': 0, 'like_c...               False
#
#                   created_at          id  \
# 0   2009-12-28T14:44:23.000Z  7124239706
# 1   2009-12-19T08:14:10.000Z  6824169402
# 2   2009-12-14T16:39:30.000Z  6666367314
# 3   2009-12-11T21:36:20.000Z  6579522012
# 4   2009-11-18T17:19:43.000Z  5831602627
# 5   2009-10-31T23:21:27.000Z  5325182843
# 6   2009-10-28T13:55:51.000Z  5230582388
# 7   2009-10-27T15:39:49.000Z  5203312011
# 8   2009-10-04T16:44:33.000Z  4606126236
# 9   2009-08-31T20:22:35.000Z  3672866109
# 10  2009-08-27T16:33:04.000Z  3582429334
# 11  2009-08-27T16:29:08.000Z  3582346717
# 12  2009-08-27T16:20:31.000Z  3582175221
# 13  2009-08-27T16:18:58.000Z  3582143508
# 14  2009-08-18T15:41:40.000Z  3384497158
# 15  2009-08-14T13:17:30.000Z  3307178956
# 16  2009-08-06T10:34:41.000Z  3164536621
# 17  2009-08-02T17:37:36.000Z  3089215447
# 18  2009-07-30T23:22:39.000Z  2940263931
# 19  2009-07-15T20:41:06.000Z  2657464202
# 20  2009-07-01T03:12:46.000Z  2414529462
# 21  2009-06-23T07:22:50.000Z  2291659294
# 22  2009-06-16T19:42:43.000Z  2196619430
# 23  2009-06-13T04:20:47.000Z  2150229065
# 24  2009-06-12T17:53:44.000Z  2134326720
# 25  2009-06-12T15:16:28.000Z  2132331134
# 26  2009-06-01T19:27:53.000Z  1994790951
# 27  2009-06-01T17:45:46.000Z  1993679664
# 28  2009-04-28T16:49:16.000Z  1640441971
# 29  2009-04-28T12:30:29.000Z  1638410338
# 30  2009-04-28T12:19:42.000Z  1638350377
# 31  2009-04-13T17:26:00.000Z  1510383642
# 32  2009-03-28T19:00:13.000Z  1408247676
# 33  2009-02-24T04:56:36.000Z  1243755867
# 34  2009-01-27T19:54:31.000Z  1153044281
# 35  2009-01-26T14:39:44.000Z  1149145192
#
#                                                  text  \
# 0   The Decade In DataForbes... by their increasin...
# 1   @dmgice Yet they carry increasing value forwar...
# 2   "If the suburb is the topographical expression...
# 3   Incredible, almost all of the Uncharted voice ...
# 4   Can traditional or lofi methods of storytellin...
# 5   and the digital counterpart, now part of the N...
# 6   @chosokabe at least you weren't the only one h...
# 7   RT @spokehq: If folk art has a digital counter...
# 8   I really love the iPhone app for reading Kindl...
# 9   `NBA 2K10&#39; cover athlete Kobe Bryant takes...
# 10  RT @PR_Couture As fashion magazines slim down,...
# 11  RT @PR_Couture As fashion magazines slim down,...
# 12  As fashion magazines slim down, digital counte...
# 13  As fashion magazines slim down, digital counte...
# 14  @chipgriffin Yeah, it's strange that the bar s...
# 15  Why do kindle book cost nearly as much as thei...
# 16  Finding out that a 21stc. digital counterpart ...
# 17  @pat All those CDs are taking up precious spac...
# 18  @mikeconaty #Q2 Agreed! Having an understandin...
# 19  Analog Music Technology may in some respects r...
# 20  Me: You've enlightened us because you found a ...
# 21  @Kenny_Florian I knocked out BJ Penn w/ your d...
# 22  Please no more conference bags and useless pap...
# 23  @PolaPremiumUSA is there a digital counterpart...
# 24  Analog tv signals being murdered today by thei...
# 25  @frodusescape Also: any insight as to the rele...
# 26  Peter molyneux has created an interactive AI t...
# 27  Microsoft probably should have written Ringo a...
# 28  note: printing a selection of to-do's from Thi...
# 29  @alexknowshtml Thanks for the tip!\n\nIts stra...
# 30  note: printing a selection of to-do's from Thi...
# 31  Tricked myself into finding a digital counterp...
# 32  @totalundigital hübsche idee+schönes post, abe...
# 33  2 things that should always come with a digita...
# 34  Wondering if librarians, curators or collectio...
# 35  @HarperCollinsCa - I'm your digital counterpar...
#
#                                referenced_tweets in_reply_to_user_id
# 0                                            NaN                 NaN
# 1   [{'type': 'replied_to', 'id': '6817077662'}]            22860585
# 2                                            NaN                 NaN
# 3                                            NaN                 NaN
# 4                                            NaN                 NaN
# 5                                            NaN                 NaN
# 6   [{'type': 'replied_to', 'id': '5230536685'}]            50668973
# 7                                            NaN                 NaN
# 8                                            NaN                 NaN
# 9                                            NaN                 NaN
# 10                                           NaN                 NaN
# 11                                           NaN                 NaN
# 12                                           NaN                 NaN
# 13                                           NaN                 NaN
# 14  [{'type': 'replied_to', 'id': '3384362162'}]              803975
# 15                                           NaN                 NaN
# 16                                           NaN                 NaN
# 17  [{'type': 'replied_to', 'id': '3089184966'}]                5523
# 18                                           NaN            16796276
# 19                                           NaN                 NaN
# 20                                           NaN                 NaN
# 21  [{'type': 'replied_to', 'id': '2287143754'}]            26667184
# 22                                           NaN                 NaN
# 23  [{'type': 'replied_to', 'id': '2132093530'}]            18223354
# 24                                           NaN                 NaN
# 25  [{'type': 'replied_to', 'id': '2132271168'}]            25453200
# 26                                           NaN                 NaN
# 27                                           NaN                 NaN
# 28                                           NaN                 NaN
# 29  [{'type': 'replied_to', 'id': '1638350377'}]                8412
# 30                                           NaN                 NaN
# 31                                           NaN                 NaN
# 32  [{'type': 'replied_to', 'id': '1408236594'}]            23285494
# 33                                           NaN                 NaN
# 34                                           NaN                 NaN
# 35                                           NaN            12880012

# %%
df = pd.DataFrame(emptyData[0])

# %%
for obj in range(1,len(emptyData)):
    df = df.append(pd.DataFrame(emptyData[obj]))

# %%
df.shape
# Out:
# (6192, 16)

# %%
df_clean = df

# %%
df_clean.to_pickle("../dummy.pkl3")

# %%
df_clean = pd.read_pickle("../dummy.pkl3")

# %%
df_clean = df_clean[['lang','author_id','source','text', 'created_at']]

# %%
def isRT(text):
        if text.startswith("RT"): return "True"
        else: return "False"

# %%
df_clean['is_RT'] = df_clean['text'].map(isRT)

# %%
df_clean = df_clean[df_clean['is_RT']=="False"]

# %%
df_clean.shape
# Out:
# (3940, 6)

# %%
import seaborn as sns

# %%
sns.countplot(df_clean['lang'])
# Out:
# /Users/alexkroeker/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lang', ylabel='count'>

# %%
df_lang = df_clean.copy()
df_lang = df_lang.groupby('lang').agg({'lang':'count'})
df_lang
# Out:
#       lang
# lang
# cs       1
# de       5
# en    3922
# es       1
# in       1
# ru       1
# tl       5
# und      4

# %%
df_clean = df_clean[(df_clean['lang'] == "en")]
df_clean = df_clean.drop(['is_RT'], axis=1)

# %%
def createdAt(date):
    return date.split('-')[:1][0]

# %%
df_clean['year'] = df_clean.created_at.map(createdAt)
df_clean.head()
# Out:
#   lang author_id              source  \
# 0   en    757859  Twitter Web Client
# 1   en   6990822  Twitter Web Client
# 0   en   8178692  Twitter Web Client
# 1   en  14124777  Twitter Web Client
# 2   en  12082342  Twitter Web Client
#
#                                                 text  \
# 0  As much as I love vinyl, I should admit defeat...
# 1  Radness. Asian people, once again proving that...
# 0  I bet the fascination of things like twitter a...
# 1  @researchgoddess Lol; thanks!  I love working ...
# 2  is fixing bugs. I never liked insects and now ...
#
#                  created_at  year
# 0  2007-10-18T03:41:03.000Z  2007
# 1  2007-09-27T08:36:00.000Z  2007
# 0  2008-12-17T17:26:04.000Z  2008
# 1  2008-10-23T18:24:07.000Z  2008
# 2  2008-08-05T14:33:15.000Z  2008

# %%
df_clean = df_clean.drop(columns=['created_at', 'lang'], axis=1)
df_clean['hashtag'] = df_clean['text'].apply(lambda x: re.findall(r"#(\w+)", x))
df_clean
# Out:
#                author_id               source  \
# 0                 757859   Twitter Web Client
# 1                6990822   Twitter Web Client
# 0                8178692   Twitter Web Client
# 1               14124777   Twitter Web Client
# 2               12082342   Twitter Web Client
# ..                   ...                  ...
# 301           1337678305       GameDevbotting
# 302  1195605686983393280  Twitter for Android
# 303  1015457003475521538      Twitter Web App
# 304  1110931116167442435      Twitter Web App
# 306           2205306038      Twitter Web App
#
#                                                   text  year       hashtag
# 0    As much as I love vinyl, I should admit defeat...  2007            []
# 1    Radness. Asian people, once again proving that...  2007            []
# 0    I bet the fascination of things like twitter a...  2008            []
# 1    @researchgoddess Lol; thanks!  I love working ...  2008            []
# 2    is fixing bugs. I never liked insects and now ...  2008            []
# ..                                                 ...   ...           ...
# 301  NONDIGITAL GAMES. HOW ARE THEY RELATED TO THEI...  2020  [boardgames]
# 302  A voting system for drops. Digital content. A ...  2020            []
# 303  @PlayWarframe Why would I want to wear somethi...  2020            []
# 304  @OGJunkyard @Forbes @brave Because old media, ...  2020            []
# 306  And facial recognition is the digital counterp...  2020            []
#
# [3922 rows x 5 columns]

# %%
df_clean.to_pickle('../data_clean_en_year3.plk')

# %%
text = df_clean['text']
text = text.tolist()

# %%
for i,v in enumerate(text):
    text[i] = p.clean(v)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
pd.DataFrame(text).to_pickle("../text_preprocessing3")

# %%
def txt_cleaner(text):
    
    text = text.encode(encoding="ascii", errors="ignore")
    text = text.decode() # removing unicode from the text 
    
    text = p.clean(text)
    
    text = text.lower() #lowering all the text
    
    punct = set(string.punctuation)
    text = "".join([ch for ch in text if ch not in punct]) #remove punctation
    
    stop_words = set(stopwords.words("english"))
    text = " ".join([word for word in text.split() if word not in stop_words]) #remove stopwords
    # try out stemming and lemmatization
    return text

# %%
df_clean['text'] = df_clean.text.map(txt_cleaner)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(df_clean['text']))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
documents = df_clean['text']

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

true_k = 4
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

print("\n")
print("Prediction")

Y = vectorizer.transform(["Azure is the leading IOT"])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["Data Analysis is a trend for amp"])
prediction = model.predict(Y)
print(prediction)
# Out:
# Top terms per cluster:
# Cluster 0:
#  digital
#  counterpart
#  counterparts
#  physical
#  ask
#  readers
#  analog
#  tool
#  abandon
#  paper
# Cluster 1:
#  clicks
#  eyes
#  newsweek
#  covers
#  cues
#  catch
#  taking
#  magazine
#  magazines
#  time
# Cluster 2:
#  land
#  nod
#  day
#  storing
#  securing
#  counterpartive
#  ara
#  premises
#  receptionists
#  logging
# Cluster 3:
#  costa
#  guilherme
#  related
#  nondigital
#  games
#  counterparts
#  digital
#  indiegametrends
#  gamedevbrbot
#  eyesavaging
#
#
# Prediction
# [0]
# [0]
